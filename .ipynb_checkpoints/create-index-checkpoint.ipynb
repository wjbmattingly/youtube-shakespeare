# %%
from txtai.embeddings import Embeddings
import pandas as pd

# %%
df = pd.read_csv("data/shakespeare.csv")
df
# Out:
#         Dataline            Play  PlayerLinenumber ActSceneLine  \
# 0              1        Henry IV               NaN          NaN
# 1              2        Henry IV               NaN          NaN
# 2              3        Henry IV               NaN          NaN
# 3              4        Henry IV               1.0        1.1.1
# 4              5        Henry IV               1.0        1.1.2
# ...          ...             ...               ...          ...
# 111391    111392  A Winters Tale              38.0      5.3.180
# 111392    111393  A Winters Tale              38.0      5.3.181
# 111393    111394  A Winters Tale              38.0      5.3.182
# 111394    111395  A Winters Tale              38.0      5.3.183
# 111395    111396  A Winters Tale              38.0          NaN
#
#                Player                                         PlayerLine
# 0                 NaN                                              ACT I
# ...

# %%
lines = df.PlayerLine.tolist()

# %%
embeddings = Embeddings({"path": "sentence-transformers/all-MiniLM-L6-v2"})

# %%
embeddings.index([(i, line, None) for i, line in enumerate(lines)])

# %%
embeddings.save("models/shakespeare")

# %%
df.loc[69148]
# Out:
# Dataline                               69149
# Play                A Midsummer nights dream
# PlayerLinenumber                        85.0
# ActSceneLine                             NaN
# Player                               Pyramus
# PlayerLine                     Stabs himself
# Name: 69148, dtype: object

# %%
for index, score in embeddings.search("knife", 25):
    print(index)
    print(df.loc[index].Player)
    print(df.loc[index].PlayerLine)
    print(score)
    print()
# Out:
# 52655
# EDGAR
# What means that bloody knife?
# 0.6581855416297913
#
# 99286
# TROILUS
# The knife that made it.
# 0.6503617167472839
#
# 53520
# ROSALINE
# No point, with my knife.
# 0.6144242286682129
#
# 56185
# LADY MACBETH
# That my keen knife see not the wound it makes,
# 0.5771658420562744
#
# 102820
# ACHILLES
# Sheathes his sword
# 0.5718309283256531
#
# 10137
# CLIFFORD
# Stabbing him
# 0.5698238015174866
#
# 10139
# QUEEN MARGARET
# Stabbing him
# 0.5698238015174866
#
# 57628
# First Murderer
# Stabbing him
# 0.5698238015174866
#
# 3111
# FALSTAFF
# Stabbing him
# 0.5698237419128418
#
# 74190
# Clown
# is stabbing.
# 0.5598883628845215
#
# 37278
# BARDOLPH
# knives to cut one another's throats?
# 0.5563380718231201
#
# 97969
# TITUS ANDRONICUS
# Give me thy knife, I will insult on him,
# 0.5501236319541931
#
# 8051
# SUFFOLK
# I wear no knife to slaughter sleeping men,
# 0.5477218627929688
#
# 71543
# CLAUDIO
# curiously, say my knife's naught. Shall I not find
# ...
